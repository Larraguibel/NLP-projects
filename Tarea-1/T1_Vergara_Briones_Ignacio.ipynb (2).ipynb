# %% [markdown]
# Pontificia Universidad Católica de Chile <br>
# Departamento de Ciencia de la Computación <br>
# IIC3670 -	Procesamiento de Lenguaje Natural<br>
# Segundo Semestre 2025<br>
#
#
# <h1><center>Tarea 1</center></h1>
#         Profesor: Marcelo Mendoza<br>
#         Fecha de entrega: 10 de Septiembre
#
#
# ---

# %% [markdown]
# ## Indicaciones
#
# Deberás entregar **SOLO** el archivo .ipynb en el buzón respectivo en canvas.
#
# **IMPORTANTE**:
# - Se te dará puntaje tanto por código como por la manera en la que respondas las preguntas planteadas.
# - El notebook debe tener todas las celdas de código ejecutadas.
# - Cualquier instancia de copia resultará en un 1,1 como nota de curso.
#
# ---

# %% [markdown]
# ## **Integrantes**:
# * Integrante1: Diego Larraguibel.
#
# * Integrante2: Ignacio Vergara.

# %% [markdown]
# ## Librerias

# %%
#AQUI importa las librerias extras que vayas a ocupar
#TODO
from sklearn.datasets import fetch_20newsgroups
from sklearn.feature_extraction.text import CountVectorizer
from nltk.corpus import stopwords
from nltk.tokenize import RegexpTokenizer, sent_tokenize
from nltk.stem import WordNetLemmatizer
from nela_features.nela_features import NELAFeatureExtractor
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from wordcloud import WordCloud
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from nltk.util import ngrams
import collections
# Out:
# pygame 2.6.1 (SDL 2.28.4, Python 3.10.8)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %% [markdown]
# ### Referencias de los Datasets
#
# De todas formas, los csv se encontrarán disponibles en Canvas
#
# * El dataset a utilizar para la parte 2 fue extraído de: https://www.kaggle.com/datasets/luisdiegofv97/imdb-dataset-of-50k-movie-reviews-spanish
#
# * El dataset a utilizar para la parte 3 fue extraído de: https://huggingface.co/datasets/mltrev23/financial-sentiment-analysis/blob/main/archive.zip

# %% [markdown]
# # Parte 1: NELA Features (15 puntos)

# %% [markdown]
# Usa 'fetch_20newsgroups' para obtener los datos a utilizar tanto de train como de test

# %% [markdown]
# **RESPUESTA**:

# %%
X_trainfecth, y_train = fetch_20newsgroups(subset='train', remove=('headers', 'footers', 'quotes'), return_X_y=True)
X_testfecth, y_test = fetch_20newsgroups(subset='test', remove=('headers', 'footers', 'quotes'), return_X_y=True)

# %% [markdown]
# ### 1.1 Análisis descriptivo (5 puntos)

# %% [markdown]
# Realiza el preprocesamiento de datos (hint: STOPWORDS, Tokenizer, Lemmatizer etc. Utilice lo que crea que es mejor para su modelo).

# %%
from nltk.corpus import stopwords
from nltk.tokenize import RegexpTokenizer, sent_tokenize
from nltk.stem import WordNetLemmatizer

# Load stop-words
stop_words = set(stopwords.words('english'))

# Initialize tokenizer
# It's also possible to try with a stemmer or to mix a stemmer and a lemmatizer
tokenizer = RegexpTokenizer('[\'a-zA-Z]+')

# Initialize lemmatizer
lemmatizer = WordNetLemmatizer()

def tokenize(document):
    words = []

    for sentence in sent_tokenize(document):
        tokens = [lemmatizer.lemmatize(t.lower()) for t in tokenizer.tokenize(sentence) if t.lower() not in stop_words and len(t) > 2]
        words += tokens
    text = " ".join(words)
    return text

# %%
corpus_train = []
corpus_test = []

for review in X_trainfecth:
    document = tokenize(review)
    corpus_train.append(document)


for review in X_testfecth:
    document = tokenize(review)
    corpus_test.append(document)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 5
#       2 corpus_test = []
#       4 for review in X_trainfecth:
# ----> 5     document = tokenize(review)
#       6     corpus_train.append(document)
#       9 for review in X_testfecth:
#
# Cell In[3], line 19, in tokenize(document)
#      16 words = []
#      18 for sentence in sent_tokenize(document):
# ---> 19     tokens = [lemmatizer.lemmatize(t.lower()) for t in tokenizer.tokenize(sentence) if t.lower() not in stop_words and len(t) > 2]
#      20     words += tokens
#      21 text = " ".join(words)
#
# Cell In[3], line 19, in <listcomp>(.0)
#      16 words = []
#      18 for sentence in sent_tokenize(document):
# ---> 19     tokens = [lemmatizer.lemmatize(t.lower()) for t in tokenizer.tokenize(sentence) if t.lower() not in stop_words and len(t) > 2]
#      20     words += tokens
#      21 text = " ".join(words)
#
# File c:\Users\ignav\AppData\Local\Programs\Python\Python310\lib\site-packages\nltk\stem\wordnet.py:85, in WordNetLemmatizer.lemmatize(self, word, pos)
#      60 def lemmatize(self, word: str, pos: str = "n") -> str:
#      61     """Lemmatize `word` by picking the shortest of the possible lemmas,
#      62     using the wordnet corpus reader's built-in _morphy function.
#      63     Returns the input word unchanged if it cannot be found in WordNet.
#    (...)
#      83     :return: The shortest lemma of `word`, for the given `pos`.
#      84     """
# ---> 85     lemmas = self._morphy(word, pos)
#      86     return min(lemmas, key=len) if lemmas else word
#
# File c:\Users\ignav\AppData\Local\Programs\Python\Python310\lib\site-packages\nltk\stem\wordnet.py:41, in WordNetLemmatizer._morphy(self, form, pos, check_exceptions)
#      31 """
#      32 _morphy() is WordNet's _morphy lemmatizer.
#      33 It returns a list of all lemmas found in WordNet.
#    (...)
#      37 ['us', 'u']
#      38 """
#      39 from nltk.corpus import wordnet as wn
# ---> 41 return wn._morphy(form, pos, check_exceptions)
#
# File c:\Users\ignav\AppData\Local\Programs\Python\Python310\lib\site-packages\nltk\corpus\reader\wordnet.py:2109, in WordNetCorpusReader._morphy(self, form, pos, check_exceptions)
#    2106     forms = apply_rules([form])
#    2108 # 2. Return all that are in the database (and check the original too)
# -> 2109 return filter_forms([form] + forms)
#
# File c:\Users\ignav\AppData\Local\Programs\Python\Python310\lib\site-packages\nltk\corpus\reader\wordnet.py:2098, in WordNetCorpusReader._morphy.<locals>.filter_forms(forms)
#    2096             if form not in seen:
#    2097                 result.append(form)
# -> 2098                 seen.add(form)
#    2099 return result
#
# KeyboardInterrupt:

# %% [markdown]
# Cree una nube de palabras utilizando el dataset de entrenamiento (una vez tokenizado). Haga uno para el primer elemento del dataset y otro para todos los elementos del dataset. Les puede servir: https://www.kaggle.com/code/anandhuh/word-cloud-in-python-for-beginners

# %% [markdown]
# RESPUESTA:

# %% [markdown]
# Muestra para el primer documento del df de entrenamiento limpiado previamente

# %%
# Para el primer documento del dataset de entrenamiento.
word_cloud1 = WordCloud(collocations = False, background_color = 'white', width = 2048, height = 1080).generate(corpus_train[0])
plt.imshow(word_cloud1, interpolation='bilinear')
plt.axis("off")
plt.show()

# Para todos los elementos del dataset de entrenamiento.
corpus_mixed = corpus_train[0]
for doc in corpus_train[1:]:
    corpus_mixed += ' ' + doc
word_cloud2 = WordCloud(collocations = False, background_color = 'white', width = 2048, height = 1080).generate(corpus_mixed)
plt.imshow(word_cloud2, interpolation='bilinear')
plt.axis("off")
plt.show()

# %% [markdown]
# Visualiza los 10 bigramas más comunes del corpus

# %%
esBigrams = ngrams(corpus_mixed.split(), 2)
esBigramFreq = collections.Counter(esBigrams)

# what are the ten most popular ngrams in this Spanish corpus?
esBigramFreq.most_common(10)
# Out:
# [(("'ax", "'ax"), 56158),
#  (('max', "'ax"), 4340),
#  (("'ax", 'max'), 4306),
#  (('would', 'like'), 429),
#  (('united', 'state'), 301),
#  (('anyone', 'know'), 294),
#  (('new', 'york'), 284),
#  (('year', 'ago'), 260),
#  (('last', 'year'), 258),
#  (('thanks', 'advance'), 236)]

# %% [markdown]
# **RESPUESTA**: Apoyo en [Fuente ngrams](https://www.kaggle.com/code/rtatman/tutorial-getting-n-grams)

# %% [markdown]
# ¿Qué bigramas y palabras son más comunes en el corpus? ¿Aparece algo raro? HINT: Pueden aparecer elementos que parecieran palabras pero no lo son

# %% [markdown]
# **RESPUESTA**:

# %% [markdown]
# Explique para que se utiliza Lemmatizer, tokenizer y stopwords.

# %% [markdown]
# **RESPUESTA**:

# %% [markdown]
# ## 1.2 Nela Features (5 puntos)

# %% [markdown]
# Extraiga características utilizando NELA. Basta con que ocupe una de las características y NO puede utilizar extract_styles. Hint: Recordar que si largo del documento es 0, entonces debe generar un vector del tamaño de las características que vaya a utilizar.

# %% [markdown]
# EJEMPLO: Cuando se utilizaba nela.extract_style se extraen 50 features y por lo tanto se tienen vectores de tamaño 50. Si el largo del documento es 0, no se puede extraer las características (porque no hay documento) y por lo tanto se debe generar un vector del mismo tamaño (50 en este caso) rellenado de 0. Este vector lo pueden llamar como 'vector cero' o 'vector nulo'.

# %% [markdown]
# **RESPUESTA**:

# %% [markdown]
# Utilizar modelo de la AF2: MultinomialNB. Recuerde que se transforma a np.array

# %% [markdown]
# **RESPUESTA**:

# %% [markdown]
# Utilice la matriz de confusión para evaluar el rendimiento del modelo. Es una buena forma de visualizar el desempeño

# %% [markdown]
# **RESPUESTA**:

# %% [markdown]
# ¿Qué ocurre con el modelo? ¿Funciona bien o mal? ¿Qué está tratando de hacer con los datos y cuál es su objetivo? Fundamente

# %% [markdown]
# **RESPUESTA**:

# %% [markdown]
# ¿Cómo se compara con el resultado obtenido en la AF2? (puede revisar el github, donde se encontrarán las soluciones de las actividades formativas)

# %% [markdown]
# **RESPUESTA**:

# %% [markdown]
# ¿Qué se podría realizar para mejorar la precisión del modelo?

# %% [markdown]
# **RESPUESTA**:

# %% [markdown]
# ## 1.3: TF-IDF (5 puntos)

# %% [markdown]
# Dado que es posible que haya malos resultados, se probará otra forma de entrenar y clasificar estos textos. Utilice un modelo TF-IDF para representar los documentos

# %% [markdown]
# Separe la data en X_train, y_train, X_test e y_test

# %% [markdown]
# **RESPUESTA**: La separación fue hecha en el fetcheo de los datos, se transforman X_train y X_test

# %%
# Usando lo visto en clases de Tf-Idf
from sklearn.feature_extraction.text import TfidfVectorizer

vectorizer = TfidfVectorizer()
X_train = vectorizer.fit_transform(corpus_train)
X_test = vectorizer.transform(corpus_test)

# %% [markdown]
# Utilice TfidfVectorizer para transformar los textos en vectores TF-IDF.

# %% [markdown]
# **RESPUESTA**:

# %% [markdown]
# Utilice la librería make_pipeline de sklearn que incluye el TfidfVectorizer y el clasificador que desee utilizar (por ejemplo, SGDClassifier o LogisticRegression).

# %% [markdown]
# **RESPUESTA**:

# %%
from sklearn.pipeline import make_pipeline
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

clf =  LogisticRegression(max_iter=1000)
clf.fit(X_train, y_train)
y_predict = clf.predict(X_test)
print(classification_report(y_test, y_predict))

c = make_pipeline(vectorizer, clf)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.50      0.48      0.49       319
#            1       0.64      0.69      0.67       389
#            2       0.65      0.57      0.61       394
#            3       0.65      0.64      0.65       392
#            4       0.72      0.67      0.69       385
#            5       0.79      0.72      0.76       395
#            6       0.75      0.78      0.76       390
#            7       0.77      0.68      0.72       396
#            8       0.49      0.81      0.61       398
#            9       0.80      0.82      0.81       397
#           10       0.91      0.88      0.89       399
#           11       0.89      0.67      0.76       396
#           12       0.56      0.61      0.58       393
#           13       0.74      0.80      0.77       396
#           14       0.72      0.76      0.74       394
#           15       0.64      0.78      0.70       398
#           16       0.59      0.68      0.63       364
#           17       0.87      0.72      0.79       376
#           18       0.55      0.46      0.50       310
#           19       0.47      0.19      0.27       251
#
#     accuracy                           0.68      7532
#    macro avg       0.68      0.67      0.67      7532
# weighted avg       0.69      0.68      0.68      7532

# %% [markdown]
# ¿Por qué cambió los resultados?

# %% [markdown]
# **RESPUESTA**:

# %% [markdown]
# # Parte 2: Word2Vec (20 puntos)

# %% [markdown]
# ### 2.1 Teóricas (5 puntos)

# %% [markdown]
# Para resolver las preguntas deberá utilizar la siguiente página: https://projector.tensorflow.org

# %% [markdown]
# En la página entregada anteriormente, use el tensor 'Word2Vec 10k', busque la palabra 'learning' con 20 vecinos y anote las 3 palabras más parecidas y las 3 más alejadas, dejando claramente a que categoría pertenece y dejando los valores correspondiente al usar la distancia del coseno. Para la reducción de dimensionalidad, mantenga el uso de PCA.

# %% [markdown]
# **RESPUESTA**:

# %% [markdown]
# Las tres palabras más parecidas a "learning" bajo la distancia del coseno corresponden a "studying" ($0.67$), "creating" ($0.668$) y "motivation ($0.666$) y las tres menos parecidas corresponden a "cognitive" ($0.571$), "teaching" ($0.565$) y "knowledge" ($0.565$).
#
# ## TODO: A qué se refiere con categoría acá? y los valores que entrega son de similitud o distance?

# %% [markdown]
# ¿Qué mide la distancia del coseno y que relación hay con la similitud del coseno?

# %% [markdown]
# **RESPUESTA**:

# %% [markdown]
# Por otro lado, la similitud del coseno mide, valga la redundancia, cuan similares son dos vectores en cuánto a orientación. Para ello calcula el coseno del ángulo entre estos, por lo que a menor angulo, mayor similitud ($\cos(\theta) \sim 1$ para $\theta \sim 0$). Se calcula como
#
# $$
# \operatorname{sim}_{cos}(x, y) = \frac{x\cdot y}{\|x\|\|y\|}
# $$
#
# La distancia del coseno mide cuán diferentes son dos vectores en cuanto a orientación, realiza esto calculando el complemento de la similitud entre ellos, es decir cuan lejano se encuentran los vectores de ser iguales en ángulo. Se calcula como
#
# $$d_{cos}(x, y) = 1 - \operatorname{sim}_{cos}(x, y) = 1 - \frac{x\cdot y}{\|x\|\|y\|}$$

# %% [markdown]
# Explique la relación de los valores obtenidos anteriormente con las palabras encontradas

# %% [markdown]
# **RESPUESTA**:

# %% [markdown]
# El vector que representa a la palabra "learning" tiene una orientación similar a los vectores asociados a "studying", "creating" y "motivation", por lo que su producto punto se maximiza y con ello su similitud, por otro lado, aquellas palabras con menor similitud al no lograr maximizar tanto el producto punto se infiere que tienen una orientación menos similar por lo que se entiende que son palabras menos relacionadas.

# %% [markdown]
# Fuentes: [Fuente 2.1 cosine similarity y cosine distance](https://pub.aimind.so/understanding-cosine-similarity-and-cosine-distance-in-depth-cc91eac3ef2)

# %% [markdown]
# ## 2.2 Análisis de Dataset (5 puntos)

# %% [markdown]
# El archivo de canvas (Dataset) proviene de: https://www.kaggle.com/datasets/luisdiegofv97/imdb-dataset-of-50k-movie-reviews-spanish

# %% [markdown]
# ¿Qué contiene el dataset?

# %% [markdown]
# **RESPUESTA**:

# %%
import pathlib
#crea la ruta a data_T1 y dsp lee el csv
parent = pathlib.Path()
ruta = parent / 'data-T1' / 'IMDB_Dataset.csv'
df = pd.read_csv(ruta)

# %%
df.head()
# Out:
#    Unnamed: 0                                          review_en  \
# 0           0  One of the other reviewers has mentioned that ...
# 1           1  A wonderful little production. The filming tec...
# 2           2  I thought this was a wonderful way to spend ti...
# 3           3  Basically there's a family where a little boy ...
# 4           4  Petter Mattei's "Love in the Time of Money" is...
#
#                                            review_es sentiment sentimiento
# 0  Uno de los otros críticos ha mencionado que de...  positive    positivo
# 1  Una pequeña pequeña producción.La técnica de f...  positive    positivo
# 2  Pensé que esta era una manera maravillosa de p...  positive    positivo
# 3  Básicamente, hay una familia donde un niño peq...  negative    negativo
# 4  El "amor en el tiempo" de Petter Mattei es una...  positive    positivo

# %% [markdown]
# El dataset contiene reviews de películas tanto en inglés como en español, además del sentimiento asociado a la review (este también se encuntre tanto en inglés como en español).

# %% [markdown]
# ¿Cuántas filas tiene el dataset?

# %% [markdown]
# **RESPUESTA**: El dataset tiene 50000 filas y 5 columnas

# %%
print(f"El dataset tiene {df.shape[0]} filas y {df.shape[1]} columnas")
# Out:
# El dataset tiene 50000 filas y 5 columnas

# %% [markdown]
# Vea la distribución del número de palabras mediante un gráfico

# %% [markdown]
# **RESPUESTA**:

# %%
palabras_en = [len(i) for i in df["review_en"]]
palabras_es = [len(i) for i in df["review_es"]]


palabras_counts_en = {}
for cant in palabras_en:
    if cant in palabras_counts_en:
        palabras_counts_en[cant] += 1
    else:
        palabras_counts_en[cant] = 1

sorted_counts_en = sorted(palabras_counts_en.items())

x_en, y_en = zip(*sorted_counts_en)

palabras_counts_es = {}
for cant in palabras_es:
    if cant in palabras_counts_es:
        palabras_counts_es[cant] += 1
    else:
        palabras_counts_es[cant] = 1

sorted_counts_es = sorted(palabras_counts_es.items())

x_es, y_es = zip(*sorted_counts_es)

# Graficar la distribución de frecuencia de palabras en reviews en inglés y español 
fig, axes = plt.subplots(1, 2, figsize=(15, 4), constrained_layout=True)
ax1, ax2 = axes

ax1.plot(x_en, y_en, 'bo-', markersize=8)
ax1.set_title('Distribución de frecuencias de palabras en reviews en inglés')
ax1.set_xlabel('Cantidad de palabras')
ax1.set_ylabel('Frecuencia')
ax1.grid(True)

ax2.plot(x_es, y_es, 'bo-', markersize=8)
ax2.set_title('Distribución de frecuencias de palabras en reviews en español')
ax2.set_xlabel('Cantidad de palabras')
ax2.set_ylabel('Frecuencia')
ax2.grid(True)
plt.show()

# %% [markdown]
# De los gráficos anteriores se puede observar que existe una clara concentración de reviews con una cantidad de palabras en torno a $1000$ con un fuerte decaimiento a casos extremos inclusive llegando casi a $14.000$ palabras.

# %% [markdown]
# Crea una nube de palabras para el dataset mostrando las palabras más frecuentes en el texto. Primero utilice para el corpus la concatenación de todos los textos de la columna "review_es" y luego realice tokenización y genere otra nube de palabras.

# %% [markdown]
# **RESPUESTA**:

# %%
concat_es = df["review_es"].str.cat(sep=' ')
word_cloud3 = WordCloud(collocations = False, background_color = 'white', width = 2048, height = 1080).generate(concat_es)
plt.imshow(word_cloud3, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
# Ahora tokenizando, se modifica el tokenizer para español
import re
from nltk.stem.snowball import SnowballStemmer
# Load stop-words
stop_words_es = set(stopwords.words('spanish'))

# Initialize tokenizer
# It's also possible to try with a stemmer or to mix a stemmer and a lemmatizer
tokenizer_es = RegexpTokenizer(r'\w+', flags=re.UNICODE)   # Para permitir tildes en las palabras y ñ´s

# Initialize lemmatizer (especial para el español)
stemmer = SnowballStemmer('spanish')

def tokenize_es(document):
    words = []

    for sentence in sent_tokenize(document, language='spanish'):
        for t in tokenizer.tokenize(sentence):
            t = t.lower()
            if t not in stop_words and len(t) > 2:
                words.append(stemmer.stem(t))
    text = " ".join(words)
    return text


corpus_es = []

for review in df["review_es"]:
    document = tokenize_es(review)
    corpus_es.append(document)
corpus_es
# Out:
# ['uno los otros tic mencion que despu ver sol episodi estar enganch tien raz que esto exact que sucedi conmig primer cos que golp sobr fue brutal sus escen violenci inconfi que encuentr derech palabr conf este espect cul par los bil coraz mid este espect cul extra punzon con respect las drog sex violenci hardcor uso sic palabr llam que apod dad penitenciari del estad segur xim oswald centr principal ciud emerald una secci experimental prisi dond tod las lul tien frent vidri enfrent haci adentr por que privac alta agend city hog much fariari musulman gangst latin cristian italian irlandes que las espos las mir muert las relacion peligr los acuerd sombr nunc est lej dir principal atract espect cul deb hech que dond otros espect cul atrev olv dat las gen bonit pint par las audienci convencional olvid encant olvid romanc met prim episodi que vist sorprendi tan desagrad que fue surreal pod dec que estab list par ello per cuand observ desarroll gust por acostumbr los altos nivel violenci fic sol violenci sin injustici guardi torc que vendr por quel los reclus que mat orden alej con maner educ los reclus clas medi convirt perr prisi deb falt habil callejer experient prisi viend pued sent mod con que inc mod visualizaci eso pued ponert contact con lad oscur',
#  'una pequ pequ producci cnic filmaci muy incuestion muy antigu mod bbc una sensaci realism reconfort vec inc mod vec piez los actor son extrem bien eleg michael she sol tien tod polari per tien tod las voc por palmadit realment pued ver edici perfect gui por las referent las entrad del diari williams sol val pen observaci per una piez imperrement escrit realiz una producci magistral sobr uno los grand maestr comedi vid realism realment lleg cas con las pequ cos fant del guardi que lug usar las cnic sue tradicional permanec lid entonc desaparec desemp nuestr conoc nuestr sent particular con las escen relacion con orton halliwell los conjunt particular apartament con mural halliwell que decor cad superfici est terribl bien hech',
#  'pens que esta era una maner maravill pas tiemp fin seman veran demasi calient sent teatr con air acondicion observ una comedi alegr parcel simplist per log ingeni los personaj son agrad inclus asesin seri sospech pan del poz mientr que algun pued decepcion cuand dan cuent que este punt part adicci riesg pens que era una prueb que woody allen todav est control del estil que much nosotr hem crec amar esto fue una las comedi woody dar dig una cad mientr nunc qued impresion con scarlet johanson esto logr tonific imag sexy salt una jov promedi per rgic esto pued que sea joy coron carrer per fue witti diabl vist prad interes que superm una gran comedi par ver con amig',
#  'sic hay una famili dond pequ jak piens que hay zombi armari sus padr est luch tod tiemp esta pel cul lent que una telenovel repent jak decid convert rambi mat zombi ante tod cuand vas hac una pel cul deb decid thrill dram com dram pel cul vigil los padr est divorci discut com vid real lueg ten jak con armari que arruin total tod pel cul esper ver una pel cul simil una boogeym lug eso dram con algun lugar thrill sin sent sol par los log padr descens los padr los padr cuant los dispar con jak simplement ign ral',
#  'amor tiemp pett mattei una pel cul visual impresion par ver mattei nos ofrec retrat vid sobr las relacion human esta una pel cul que parec estar dici ndon diner pod xit hac las person las diferent situacion que encontr esta una variaci desemp arthur schnitzl sobr mism tem director transfier acci actual nuev york dond tod estos personaj diferent nen conect cad uno est conect una maner otro siguient person per nadi parec conoc punt contact anterior con estil pel cul tien aspect lujos sofistic nos tom par ver viv estas person mund que viv propi bitat nic cos que sal tod estas almas imag son las diferent etap soled cad uno habit una gran ciud exact mejor lug que las relacion human encuentr cumplimient sincer que discern cas con mayor las person que encontr actuaci buen baj direcci del mattei stev buscemi rosari dawson carol kan michael imperioli adri greni rest del talent elenc hac que estos personaj cobr vid les des que mattei teng buen suert esper ansi xim trabaj',
#  'probabl pel cul favorit tod los tiemp una histori desinteres sacrifici dedicaci una caus nobl per predic aburr simplement nunc envejec pes hab vist unas vec los ltim rendimient paul luk tra grim mis ojos bett davis uno sus muy poc rol verdader simp tic una deleit los son com dic abuel com vest enan que los per eso sol los hac divert ver lent despert madr que est suced mund baj propi tech cre ble sorprendent tuv una docen pulgar tod ser arrib par esta pel cul',
#  'segur que gust ver una resurrecci una seri seahunt dat con tecnolog que tien hoy tra emoci del crec televisi blanc negr junt mar con armas arma eran mis roes tod las seman vot por regres una nuev caz mar necesit cambi ritm televisi esto funcion par mund aventur baj agu por ciert graci por punt vist par ver much punt vist sobr televisi elmuch pel cul que cualqui otra maner cre que teng que quier dec ser buen leer algun punt sobr squed del mar mis rim ser neas dej present dej sal ten dud quit esto entonc deb irme que hag',
#  'este espect cul fue una ide incre ble fresc innov los cuand emiti por primer vez los primer fueron brillant per las cos dej despu eso par espect cul era realment divert contin descens complet rdid tiemp que hoy verdader vergonz hast punt este espect cul escritur dolor mal las actuacion son casi tan mal par respir levement entreten los hosts invit este program probabl estar air result tan dif cil cre que mism creador que seleccion man repart original tambi eligi band hacks que sigu pued reconoc ese brill lueg verl adecu par reemplaz con tal mediocr sent que deb darl estrell del respet por elenc original que hiz que este program fuer gran xit com ahor espect cul simplement horribl pued cre que todav est air',
#  'alent por los comentari posit sobr esta pel cul aqu estab des ver esta pel cul mal error vist pel cul esto verdader uno los peor ellos horribl casi tod los sent edici ritm histori actuaci sol canci pel cul una melod coj juegamen cuatr vec pel cul barat desagrad aburr extrem rar vez estad tan feliz ver los dit final una pel cul nic que impid dar esto puntaj harvey keitel mientr que esto est lej mejor rendimient men parec estar hac poc esfuerz uno sol par obses keitel',
#  'gust ris original desgarr gust esta pel cul eres jov viej encant esta pel cul infiern inclus mam gust campament great',
#  'phil ali gen una esas pel cul peculiar dond humor bas rarez tod lug los punchlin real prim lug fue muy extra bastant divert per med que avanz pel cul encontr los chist rarez una pel cul baj presupuest eso nunc problem mism hub algun personaj bastant interes per eventual acab perd inter imagin que esta pel cul atra ston que particip actual par algo simil per mejor intent hermanod otro planet',
#  'esta pel cul cuand ten alrededor cuand sal recuerd que escen aterr era gran ave que com los hombr colg impotent los parac das just fuer del air horror horror jov yend estas pel cul cheesy los bad por tard todav estab cans rmul par estas pel cul tip monstru que usual inclu roe una hermos muj que podr ser hij profesor una resoluci feliz cuand monstru muri final import much por ngul rom ntic com las parcel predec los amo ahor par humor involuntari per aproxim men psycho cuand sal encant que estrell janet leigh fue golp tempran pel cul sent cuent ese moment dad que los guionist est invent histori aseg res ser aterr posibl una rmul bien usad hay regl',
#  'que soy gran fan tic del trabaj boll per nuev much son disfrut postal pel cul tal vez soy nic casc aparent compr los derech par usar con diferent much tiemp inclus antes que jueg hay finaliz las person que han disfrut mat mercs infiltr laboratori secret investigaci ubic una isla tropical deb ser advert que esto est muy lej esto algo que boll unid junt con legi schmucks sent loneley set boll invit tres sus compatriot par jug estos jugador van por los nombr til schweig udo kier ralf moell tres los nombr que realment los han hech bastant grand pel cul biz que cuent jack carv interpret til schweig carv alem tod twurst com dud verdader tod agend carv per sol vim carv una perspect primer person por que realment sab que parec cuand estab pat sin embarg histori esta pel cul est los mon vem malv cient fic loc krieg interpret por udo kier que hac que los sold gen tic mut gms med que llam realiz investigaci secret una isla que recuerd spoil vancouv por algun raz eso tien palmer aqu lug ten bonit ador ric mader siqu nos hem ido much antes empez llor meheh pued continu quier manten fiel los chulol shenanigans vay ver esta pel cul sent decepcion decepcion verdader experient boll que signif mayor ella chup hay algun cos que val pen mencion que implic que boll hiz buen trabaj algun reas pel cul com algun bonit escen bot luch hast que tod escuadr gms crom albin entra escen tod hac pel cul llor lej scheiss eso cac par simplon quier tom wiff adel btw carv obtien comp ero muy molest que hac quer dispar los primer tres minut que est pantall',
#  "repart jug shakespear shakespear perd apreci que esto est trat tra shakespear las mas per por arruin algo tan buen porqu 'the scottish play' shakespear favorit que que ciert agol part bowdl por tant bowdlerization trat hac algo simil era victorian otras palabr pued mejor perfecci teng que escrib per com teng que escrib men diez neas deel text composici ingles nunc fue fuert sol tendr que segu adel dec que esta pel cul com dic dich simplement reduc",
#  'esta una fant stic pel cul tres prisioner que hac famos uno los actor georg clooney soy fan per este roll mal otra cos buen pel cul band sonor hombr tristez constant recom esta pel cul tod salud bart',
#  'tip las escen tic sol par dart cuent que era uno los bits pel cul aficion incre bles que vist tip proyect cin secundari pens rosann arquett fue con tod esos personaj accion ese extra puebl medi oest bastant dif cil involucr con este hay leccion que aprend ella hay ide brillant simplement ntim bastant rid cul per much piel eso intrig grab vide sin sent que fue con relaci bisexual nad despu tod los encuentr heterosexual estab con esa danz absurd con tod jug sus rol estereotip este pas com mill otras mill pel cul mal desperdici diner que podr hab gast hambr sid fric',
#  'algun pel cul simplement deb ser rehaccion este uno ellos mism una mal pel cul per pued captur sabor terror pel cul del mism tul liam neeson fue excelent que siempr mayor part del repart detien con excepci owen wilson qui simplement traj sensaci correct car cter luk per fall import con esta versi que desvi demasi lej histori shirley jackson sus intent ser grandios perdi part emoci pel cul anterior una compensaci par los efect especial suav una vez dir que mism una mal pel cul per disfrut fricci del terror versi anterior much',
#  'esta pel cul convirti una las mejor pel cul horribl horribl hab minut continu dond hab una pele con monstru otro hab posibil que ning desarroll personaj estab demasi ocup corr una luch espad otra tuv apeg emocional except gran quin mal que quer destru las escen fueron descar rob otras pel cul lotr star wars matrix ejempl escen fantasm final fue rob escen final las viej guerr star con yod obe one vad quin ara principi era exact com frod atac por ara cambi los rey elijah wood ctim ambas pel cul esper hypnotiz picadur ctim las envuelv hol tod quin contr tem los human fue matrix terminator hay ejempl per por perd tiemp algui dir que estab con los nazis los nazis hab una nea histori juvenil apresur una conclusi juvenil pel cul pod decid era una pel cul par una pel cul par adult tampoc era much simplement desagrad una verdader decepci por dec men ahorr diner',
#  'recuerd esta pel cul fue primer pel cul que hab vist cin fot era oscur los lugar estab muy nervios estab vuelt pap llev herman herman newbury cinem newbury berkshir inglaterr recuerd los tigr gran cantid niev pel cul tambi aparici del actor adams grizzly dan haggery cre que uno los tigr disp muer algui sab nde encontr esto dvd etc gamel sab cin ahor convert gimnasi que una verg enza muy grand que cin cercan est mill distanci encant escuch otros que han vistoest pel cul cualqui otra com ella',
#  'una pel cul horribl deb hab estad contr algun apest real par ser nomin par gold glob han tom histori del prim pintor renacent femenin famos destroz del reconoc quej que hay tom libertad con los hech histori fuer buen eso podr estar perfect bien per simplement extra por tod las cuent verdader histori este artist habr logr una pel cul much mejor por les ocurri este script sord aburr supong que hab suficient person desnud versi ctic est corr apresur final con resum vid del artist podr amos hab salv par hor hab favorec rest pel cul con mism breved',
#  "despu del xit muert trat que trat que sea sorprendent que realid cad exces mor dur pel cul cobr tip equivoc lug equivoc concept tiemp equivoc eso que hic con cliffhang mor con fuerz una mont just tiemp par rescat 'stop mam dispar stallone's car cliffhang gran sue nit pickers especial aquell que son expert escal mont bas jumping aviaci expresion facial habil actuaci general est llen excus par desped pel cul com una pil basur stallon inclus logr sal corr por caball sin embarg olvid tod las tont realid jugador muy amabl inneg entreten que ofrec una gran cantid emocion involuntari much ris tien que amar john lithgows sney malvanness garrapat cad band caj baddi mejor tod agent 'turncoat' form permanent hostiliz desventur rex linn com travers pued hab sid henry 'retrat asesin serie' per michael rook notabl por rendimient dign cresh com hal insist grit constant incredul dolor sus captor que hombr nunc lastim nadi segur parec que realment parec que personaj franc ralph wait sonr cuand cuest muert tambi deb actor 'quem londres' craig fairbrass com chic brit brit que vien cultiv mientr usa hal com tbol human pued evit disfrut tant hal necesit una buen pat que olvid mejor juici qui preocup 'es nunc podr suced baj sus expect acci enciend volum disfrut est busc qaul que llev helic pter",
#  'tuv terribl desgraci ten que ver esta pel cul total tod que teng que dec ahorr tiemp diner esto tien que ser peor pel cul tod los tiemp siqu deb llam una pel cul com una pel cul deb que fall tod los aspect que hac una buen pel cul histori interes absolut tod los actor son delg papel son cre bles tien una mal direcci las secuenci acci son tan fals casi pel cul est llen una solaner mierd que ningun person respet podr encontr diversi menor poc esta pel cul supon que est orient haci los hombr per tod las mujer son tan absolutamenteun poc atract especial esa viej cos arrug que vien haci final intent aparec sexy esos disfrac extra horribl fall miser inclus algun las pel cul rid cul todav dar algun ris per esto demasi dolor par ver',
#  'pel cul absolut impresion tien hor par mat verl lament muy divert rajnikanth llev pel cul sobr sus hombr aunqu hay nad que todav gust sic rehm tom tiemp par crec per despu que escuch unas cuant vec realment empiez gustart',
#  'prim lug vam obten algun cos direct aqu soy aban anim siempr sid hech sol ver spe rac tod tiemp preescol gust las vari pel cul porqu son hilar gust las pel cul godzill much much vec cuand enciend pel cul parec que ser pel cul usual hast mierd per tod aug repentin anim enciend esto cuand pel cul wwwaaaaayyyyyy cuest abaj animaci muy mal barat inclus peor que que recuerd spe rac par crisstak hech tan barat una las poc escen pel cul que vid recuerd cuand grup qued sin escuel son los mism una otra vez tambi terribl los dinosauri ven peor que godzill adem transici acci viv animaci desorganiz log las voc especial doblaj ingl que vio era horribl estab rog que padr sal cint del reproductor dvd vhs nic que mantuv sobreviv fue agriet brom comentari com los robots joel mik mst elig tempor honest esta nic form disfrut apen disfrut esta pel cul sobreviv mism tiemp deck estoy plan mostr esto otro comp ero otaku pal hallow par una noch cin deb que est pid bastant dolor ver involuntari divert mism tiemp doy esta pel cul una mejor del que original voy dar acuerd con escal calificaci signif bastant aburr mal tan divert com cont con tres men que encuentr una maner burl ello entonc volv tan divert com cont hast',
#  'esta fue peor pel cul que worldfest tambi recibi menor cantid aplaus despu sol pued pens que est recib dich reconoc bas cantid actor conoc pel cul genial ver beals per ella est sol pel cul durant unos minut park una actriz much mejor que part permit par rest actuaci dif cil juzg porqu pel cul tan rid cul predec personaj principal total poc intimp tic por tant orifici par ver hay una profund emocional real histori una pel cul que gir sobr actor que pued obten trabaj sient muy original par tampoc desarroll del polic sient com una las much pel cul direct vide que los siqu una buen esos est ndar',
#  'histori kar carpent muestr poc sobr vid complej cantant kar carpent aunqu fall dar hech precis detall cynthi gibb port kar fue una buen elecci ella una buen actriz per jueg muy ingenu tip carpinter kar tont cre que papel necesit car cter fuert algui con una personal fuert papel fletch que agnes carpent excelent ella hac gran trabaj com madr kar tien grand cancion que podr hab inclu lbum band sonor lament fueron aunqu esta pel cul estab cim las calif estad unid otros ses',
#  'lul una obra maestr tic viaj mareant sol vast ment asesin seri sin tambi uno director muy talent esta evident concluyent que pued logr los ser human desat sus imagin desinhib esta audaci trabaj empuj lad los pensamient par caer rmul clich cre algo verdader magn fic esta mejor pel cul del hast fech numer quej sobr esta pel cul cualqui lug tod tip estil ningun sustanci personaj mal fundament mal actuacion par critic negat esta pel cul perd punt esta pel cul pued ser hit una tradici dond ocurr futur pel cul celd acab abrir puert otro mund imaginaci entonc pod golp puert car dec director tarsem singh que quer personal gust darl bienven otra pel cul tarsem encant ver algui trat desafi tod escuch habl dentr ment asesin seri estoy acuerd que ner poc exces los estab llen pel cul que intent represent que hac que los asesinat seri registr algun ellos trabaj per mayor frac per lul arma mism sender nos dan nuev gir nos transport sic ment nos present nad men que viaj fascin materi misteri siempr estudi gust pel cul nos baul con demasi jerg cient fic trat explic jennif pez realment entra cerebr otro lug ella sol encuentr una mes laboratori est envuelt con que parec muy larg twizzlers jact otra entid celd quier dejart ver trat trat supong que eso que algun person les gust ciert gust las explic con mis pel cul per cuand una pel cul aventur nuev terren deb dej hac que dese simplement tom pel cul era muy oscur cuand mostr realid tal vez contrast brillant visual cuand encuentr dentr del cerebr otro obstant dis establec era simplement asombr sorprend esta pel cul llev cas unos poc oscars cinematograf los mejor disfrac mejor director similar estuv depend men nomin par mejor imag dad cuent que estad repit porqu hay nad que dec sin porqu pued enfatiz suficient fant stic que pens celd era entras pel cul con una ment muy abiert par que tom con las maravill una fiest cobertur ojos entonc asegur buen moment supong que esta pel cul fue poc demasi par algun person escribi ndol com extra loc estoy much psicolog imaginaci ment human que estab callej sal del teatr escuch miembr audienci dec quienqu que hay hech esa pel cul segur hiz much buen drog quier que estab fum',
#  'esta pel cul trat ser demasi cos tod vez punz tir pol tic hollywood blockbust comedi rom ntic sappy valor familiar prom list sig sig fall miser tod ellos per hub suficient inter par evit que desv hast final aunqu apreci esp ritu detr guerr inc deprim que vea esfuerz tan torp especial cuand seatom por sus objet par reflej falt existent una tic grav lug simplement mal redacci direcci producci esta pel cul particul hay una tic que deb hac sobr corporatizaci guerr per hurg divert esta maner disminu verdader atroc que est suced recuerd poc tres rey que maner simil trivializ una caus genuin preocupaci',
#  'esta pel cul fue tan frustrant tod parec rgic estab total prepar par pas buen rat men pens que podr soport per estab equivoc primer bucl rar era com ver los vide caser divert ric los maldit padr los odi much famili latin pic est reo necesit habl con person respons esto necesit ten una charl esa que siempr estab colg algui acab odi tuv que mencion ahor escen final trasciend deb dec tan glorios llen mald que una pel cul propi que bail mierd horribl hermos vez',
#  "'pel cul guerra' ner hollywood que hech rehech tant vec que log clich tram reajust las secuenci acci sobr xim sensaci parec inevit par cualqui conflict que ocup combat gran escal sin embarg vez cuand aparec una pel cul guerr que contr gran tra una histori verdader original convincent vid pantall plat era guerr civil fri mountain protagoniz por jud dery nicol kidm ren zellweg una pel cul este tip entonc llam mont cold una pel cul guerr del tod precis suficient precios pel cul abre con literal literal secuenci batall pid suci que pon verg enza glori edward zwick sin embarg mont trat guerr civil mism que sobr per odo gent los tiemp histori centr alrededor sold confeder enrojec sold desemp ado por ley jud que disgoner con espant guerr nostalgi por hermos alde mont carolin del nort bellez surhernal que dej atr ada monro interpret por nicol kidm primer vist esta configuraci aparec rmulaic med que inter rom ntic cas audienci suficient simpat las tribul reticent del sold camp batall hech los segment anterior pel cul son relat poc impresion inclus poc contraprest viv sin embarg mont sin embarg necesit gir stic que intr pid roe intrep inman result ser desertor ahorr incidental audienci del escenari potencial confus quer arraig los confeder comienz una larg odyssey inici mientr tant vuelt granj las form cultiv ada prob poc uso los camp pront transform algo wilderbeast ven rescat ada curs tiendum las nails ruby thes interpret por ren zellweg que ayud ada coloc granj quiz import enfrent soled aislamient guerr parec hab tra ada dentr estas dos configur desarroll retrat vid convincent vec muy perturb del sur rasg guerr los personaj con los que interact que interact son sorprendent complej mejor por maravill actuacion brend gleeson com padr deadbeat ruby ray winston com legisl declar natali portm com una jov madr profund problem tic aisl tod han sid consider enorm afect cambi por guerr agresi del nort mayor par peor mensaj antienvolum oscur impregn acentu por una puntuaci efect inquiet herm herm tom virgini carolin del nort comun audienci tant por las escen batall espant com por tierr cicatriz las person traumatiz par las cual guerr fue luch aunqu las armas ctic guerr han cambi much sigl pas efect infernal tierr pertinent atempor elirector anthony minghell logr manten este ambient sombr par mayor part pel cul per ambient lament denigr por lug bien climax tep que hac poc justici los personaj maravill form histori amor entre inman ada destac torpement principi final pel cul aunqu naturalez intr nsec distant abstra inclus absurd relaci una form ajust naturalez trist del rest tram hay error cold mountain tien los rasg buen romanc dram guerr inspir una visi nic una era que est segur sol entreten sin tambi par absorb verdader audienci las vid una gent desgarr por una guerr complet desesper por deshac sus terribl repercusion por complet",
#  'tens org nic crossfir edward dmytryk thrill suspens distint una pel cul improb mensaj usand aspect los disposit del cicl noir cuant washington una comp sold enfrent inquietud sal las barr tres ellos termin apartament extra dond robert ryan borrach beliger super anfitri sam leven hast muert porqu jud detectiv polic robert young investig con ayud robert mitchum que est asign atuend ryan sospech cae segund las tres georg coop que desaparec ryan mat terc amig stev brodi par asegur silenci antes que los ven cierr pay paxton dmytryk dmytryk dibuj actuacion precis sus tres bobs protagon ryan natural hac masculin blanc protot pic enoj hast empu adur mientr que mitchum sajer con alert caract stic incorporaci papel sin embarg central young pued que nunc hay sid mejor glori graham primer interpretaci total con flech del vagabund vulner vulner com sac trist que neg vid paul kelly nos persig papel pequ perif ric que hac memor dmytryk pol tic compromet quiz inevit succums sermon per est bastant limit reminiscent los ven abuel irland muri las man los fan tic sigl antes por tant por ciert estir cronolog mit men hay ning intent hac una explicaci sin embarg glib por ryan odi los jud hillbilli curi crossfir sobreviv inclus mayor cambi novel bas richard brooks ladrill foxhol trat con asesinat gay golp per homosexual todav estab lid sin embarg las notici del holocaust ten sin embarg comenz surg las ceniz europ por que hollywood sinti envalenton par registr protest contr antisemit los estudi siempr tembl ante posibil ofend cualqui posibl comprador bolet per mientr que cambi homofobi antisemit funcion general los detall ajust tan suavement ctim que charl con sold solitari solitari borrach que invit regres cas parec extra aunqu especial que hay una novi poc distanci plante cuesti este escenari mantuv inadvertid dej com una punt discret motor original que gener rabi asesin ryan',
#  'ardh saty una las mejor pel cul que hay hech cin indi dirig por gran director govind nihalani este cin paralel exit que tambi result ser xit comercial inclus hoy ardh saty una inspiraci par tod los director der indi pel cul cuent escenari vid real polic mumbai los diferent cualqui polic otras ciudad indi polic mumbai abarc sistem diferent por complet govind nihalani cre desembols muy ctic con enfoqu vid real del entorn policial mumbai vari oficial coleg polic pel cul describ histori anand velank jov polic sangr calient provenient una famili pobr padr agent polic sper mism anand sufr las ideolog incident padr las atroc padr madr enfoqu anand haci acci inmediat contr crim dese inert par propi satisfacci laboral pel cul est aqu gir una parcel que los esfuerz constant anand contr crim son pisot por sus mayor esto conduc frustracion que pued logr satisfacci laboral des result las frustracion ira expres exces violenci las sal bar remord tambi conviert alcoh lic esp ritu dentr sig viv que luch constant sistem conscient del sistem del metr dond polic los pol tic est asoci inerc con extrem lejan compromis haci ctic tic negat final suspend direcci una piez maestr cle muy dur una las mejor escen memor cuand romp cas del ngster los ngsters ram ram par arrest segu una conversaci cort que fant stic much escen pel cul tien moment levant cabell enfoqu ctic del gui golp import alcohol corrupci influenci pol tic coraj las decision son part integral polic mumbai inclus hoy esos aspect son trat brillant final las pel cul pertenec demostraci hombr puri retrat velank atraves tod sus emocion absolut brillant',
#  'primer exposici los templari una buen estab emocion encontr este tul entre las ofrend del vide anchor bay que nos tra otros sic cult com spid baby calid impresi excelent per esto sol pued ocult hech que pel cul mortal aburr hay una secuenci apertur emocion que los aldean exig una venganz terribl los templari establec tod motiv per tod dem pel cul lent pes ltim instanci sin satisfac adiend insult lesi pel cul fue apod subtitul com prometi chaquet vide',
#  "una las cit signific tod pel cul pronunci mit camin por protagon mafi hombr medi titt girolam hombr sic descript median edad original salern sur itali cuand present inici pel cul estad viv una vid hotel eleg per est ril cant switzerland habl italian durant los ltim diez realiz una empres que sol present gradual bien esta escen pivot per aparent transparent tien lug los emple del banc suiz que normal cuent efect girolam dic que lar falt malet habitual llen billet banc apil notici silenci per helad amenaz con gerent del banc coaxial quer cerr cuent mientr tant nos dic los espect que cuand acantil tien que acallart hast final sin temor ser atrap aparec rid cul dic pued aclar por tiemp lueg mit dec verd eventual hab hech esto hiz impuls sol mit dij verd hab acept las consecuent vid ltim instanci amor exact raz detr del comienz los problem titt girolam este personaj inicial antip tic cant taciturn taciturn cortadur bord hombr que siqu respond especi camarer camarer que dic hol adi conviert moment que espect preocup profund moment dad vid titt decid sent preocupaci por aparec rid cul primer mit pel cul pued ser descrit com lent por algun hech revel los las noch girolam ese hotel ritm extra deliber revel detall aparent mundan irrelev sin embarg las escen que pued hab parec innecesari revel que esencial que son com esta pel cul constru magistral innov desarroll ante sus ojos existent titt girolam hombr sin imaginaci ident vid personaj antip tic que termin inesper por que por que men pens que har tambi transmit con secuenci eleg edit uso muy interes sic uno tem los tabler band escoces can destac especial nunc fue contr entre form que hollywood itali trat los mafios desacuerd que desd liberaci pel cul com conseguenz dell'amor l'imbalsamator otro element interes fue form que pel cul hiz uso del insomni del protagon diferent del maquin una maner much expl cit insomni pel cul pacin consokenz dell'amor usa esta condici par simboliz malest emocional profund que emborr tan profund oscur del inconscient casi impos pin point caus hech hay una jov simp tic camarer del hotel sof interpret por olivi magnani niet legendari anna recuerd mejor amig titt hombr que vist inesper proporcion una pequ ventan vid que titt titt eventual aunqu tentat principi acept mir nuev aunqu nunc deletre expl cit espect sab que hombr com titt acept las consecuent del amor tendr consecuent inimagin una pel cul sin una sol escen sex violenci una pel cul que desarroll propi tiemp conced nad las expect del espect consokenz dell'amor excelent represent ese pequ tranquil renac discret que llev cab cin italian desd disminuci cinecitt durant segund mit los mund est esper que itali produzc tarif similar postin pel cul estil vit bell que descuid explor fin creacion com consueguenz dell'amor l'imbalsamator otros rdid mund",
#  'esta pel cul esper much teng paquet pel cul tod las cual eran bastant terribl maner por debaj fiv podr esper sab que ten correct tod eran terribl esta pel cul tien algun unos poc est estir ndol punt interes vist ocasional videoc mar buen toqu bater muy parec bater dec conden molest buen buen realid problem que tan aburr que sol pued asum fue intent constru tensi tod nad suced cuand hac complet tedios tuv pulg ayun bot haci adel list par presion par mayor part pel cul per dio una oportun seri cantant principal band que est muy bien porqu mencion bell que poc pens parec poc com meercat tod esto siqu mencion asesin siqu voy entrar val pen explic tod mod que respect star londr son sol nic raz par ver esto con excepci londr que realid era bastant divert fue por talent actu ciert vist much peor per tambi vist much mejor mejor evit men que est aburr ver pintur sec',
#  'compr esta pel cul blockbust por porqu son interes poc ranm esqu con ide que algui arrastr alrededor esquelet porqu hab una lind chic una minifald espald porqu hab una etiquet visualizaci restring pens que iba ser dulc men sincer histori edad con extra bord indi estab equivoc navegaci vio teng que pregunt consigui etiquet restring que casi hay lenguaj asquer poc violenci cercan desnudez honest normal esper esper cuand est camis ves sus brag ves sus brag much esta pel cul porqu import est usand una minifald alg tip inclus humor anti religi domestic coj caricatur insincer deriv poc original peor tod divert nim ser mejor escuch ray stevens jes usar rolex program televisi esto apen calific com est calific per blockbust nieg dej que cualqui person menor alquil esto com fuer pornogr fic cualqui pequ podr alquil versi edit requiem por sue per insist que zack reb peor per esa maner ciert mod esto preocup nic que qued eso podr ofend las person ide del suicidi principi algui necesit ver pel cul con suicidi honest retrat esta per mejor com los suicidi virg son adolescent ambas esas pel cul calific simplement deb aspect del suicidi entonc teng poc posibil convert una histori que estad escrib una pel cul los personaj principal tien medi doc suicidi una las tres principal caus principal muert adolescent cre que mer por que probabl que mayor los adolescent hay sid ver afect por sin embarg dir jas pel cul',
#  'parcel sobr muert los pequ tolv que tien que investig los asesinat durant pel cul parec que tien algun problem con hij final asesin seri captur eso per antes descubr qui dunnit tien que ver actor terribl por part tod los actor incre ble mal que son estos actor inclu tolv podr segu per eso gran rdid tiemp simplement veas pel cul advert',
#  "algun vez vio una pel cul que perdi parcel buen esto siqu realment ten uno par empez nde empez las escen anud nuestr her sent alrededor cas con realid hay sensaci amenaz inclus present cre inclus durant las torment ctric aparent constant que nunc escuch extra ament cas gran dobl acristal cas que aparent est sol unos kil metr una ciud encuentr vari hor pie tercer chic que tien ning prop sit par tram except par proporcion asesinat sorprendent pid gory com tedi vuelv insoport inclus comienz que sugier una pal asesinat tod rea pes que evident que asesin nunc aventur lej cas extra ritual con sal pimient que casi resum mayor las pel cul inherent falt direcci adir una actriz principal que pued actu per men est dispuest hac algun escen duch desnud complet irrelev este vide verdader desagr per form que esper continuaci simplement por ser prohib rein unid los principal deb ltim asesinat sorprendent sobr extend ofrec nad que valor curi asesinat 'daft' sic preocup telegrafi men diez minut antes despu pase por bosqu nuestr ctim lleg una pendient ascendent bastant empin que obvi luch mit camin una figur part superior vest negr bland una guad grand hac deslic haci abaj corr com rest nosotr por supuest luch contr cim par mod agrad ergu frent arma del asesinat realment sol una pel cul com dic",
#  "buen que esta seri una especi camin 'aqu vam otra vez 'la seman seman personaj dav mors ayud sal viaj que est poc pepinill per est mal con eso dav mors uno los mejor actor los personaj por ciert fresc par ten una seri cre por dav koepp gran escritor ciel deb falt amor por este espect cul por much yon pued verl una seri tempor per nunc sab cantid basur que hech que desconciert esper que algo buen pued pas una primer seri",
#  'despu sent trav esta pil esti rcol espos nos pregunt realid era product experiment par ver program comput podr produc una pel cul fue tic rmul per propagand los estad unid lanz car larg pel cul demuestr decepcion que obra los human mam ric conspiraci per cit com ten que rob declaraci independent par proteg parec que las form justific las accion com invasi irak etc hech que nichol jag gust nunc har use declaraci independent com chip negociaci con una car rect hiz pregunt espos tod repart tom valium antes dispar cad escen razon detr cad gir parcel nuev pist verdader rid cul impos segu tambi hay una parcel lateral misogini con whinch nombr fue siend reprend por tod los involucr par nunc cerr ella est clar pel cul sol par las mir per sent neces abofet tul sobr car cter par darl algo graved moment dad personaj cag dic nunc call mar sient ella mir sus man com fuer verdader grotesc nic benefici par esta pel cul fue que tan sorprendent mal obtien algun ris ella cos realment aterr que mayor las person que ven pel cul con nosotr parec disfrut espeluzn',
#  'ten tod los clich las pel cul este tip ningun sustanci tram fue ningun part final pel cul sent com lech par observ producci fue buen sin embarg gui actuaci fueron calid pel cul casting era pobr porqu hab buen actor mezcl con los actor crumby los buen actor sostuv los suy alej los dem esta pel cul dign palabr per dir par satisfac requisit nim diez neas jam wood cub goinging jueg caricatur mism otras pel cul est busc entreten sin sent todav recomend esta pel cul',
#  "esta pel cul bas libr una cos esplendor han suyin abord los problem las relacion racial entre los asi tic los blanc tem que provien las experient personal han com eurasi tic que crec chin ese antecedent hermos configuraci hong kong esta histori amor ambient nic bastant atrev por tiemp permanent que eso histori romanc estereotip con una canci memor que quiz sea record que pel cul hermos jennif jon mir part maravill desemp nomin oscar com dic raz mixt durant lleg del comun chin continental william hold nunc mejor jug una ventaj rom ntic com period que cubr las region rasg guerr mund actuaci primer categor mic entre los dos amant proporcion algun moment genuin afect pantall plat segur que derret los corazon los que inclin rom ntic cinematograf realment aport fifty's hong kong especial cim colin con vist puert dond los dos amant pas sus moment ntim final verdader lagrimoni algun pued consider los romanc sentimental pass per par aquell que disfrut las histori amor sic hollywood este ejempl brillant",
#  'tod las pel cul que vist esta rabi tien que ser una las peor peor direcci gic continu los cambi script parcel log hic grit dolor podr algui ven con algo tan crap gary busey conoc por sus pel cul per esta una pel cul segur residu trak por ejempl alrededor dos docen oficial ley del fbi las ley local rod una cas remolqu con jeep wagon dentr del jeep est confund cuant por trat tod los polic cuesti segund produc una enorm batall armas siend mat direct los polic desplieg jeep con gary comp que los estab vol los polic caen com domin jeep con gary accion alrededor rcul son golp por una sol bal pellet est mat gary parec hab not maldit sea ese tip dur verdader milagr desd que los seis dispar celebr bal hab milagr',
#  'hab escuch cos buen sobr estad graci entr con una ment abiert pens que rcit dios estab bien pens que tal vez dunescl hab mejor madur com cineast pel cul comenz con una actuaci temblor pens buen tal vez ser mejor desafortun nunc hiz imag comienz por introduc dos misioner ancian misioner mormon parec que audienci les conozc crec par preocup por ellos lug histori degener una seri alt improb desafortun event que destac desobedient flagrant por part los misioner algo que exist sin dud per rar vez nivel que repagu dutherch vuelv casi ris nic xit putch esta pel cul exit alienaci blic objet retrat maner irreal inexactitud vid los misioner mormon dutherch logr nad que enoj audienci predomin mormon pel cul ningun maner reflej realid las mision son nad com que dutch shows hab serv una stic mormon pued atestigu este hech vid pandill californi ciert contien lenguaj much expl cit que ocasional vulgar lev conclusi que estoy asum que deb toc audienci inspir cre que perd est dispon par tod fue incre ble vam tod misi par ver este ancian envi cas mam est pie just lad del otro caseos xim vez dutch intent hac una pel cul con que algui pued identific',
#  'esta pel cul golp cas por siend recuerd los padr trabaj una bric tambi pens hub trabaj dur tambi enorgullec nunc rend tambi podr ten sue american cas algun autom vil que llam sin embarg not sin tul algo diferent padr que renunci noven grad agud sent codici perez pued obten ning lad gust sab algui tien esta pel cul dvd ovhs est hech par televisi acab verl hac una hor pued encontr por ningun part encant mostr esto mis amig mis pseud amig familiar otros familiar ven que piens recu rdal que una vez los estadounidens trabaj por bien sent honor que nos enorgullec que nosotr logr cre que sensaci sig per una espiral pes haci abaj con tant cos que hac extranjer',
#  "com descarg respons vist pel cul vec los ltim acab ver musical esta seman esto permiti juzg pel cul sin ser contamin por que era estab musical sin embarg contest cuand los musical realid cre que michael dougl trabaj bastant bien ese papel junt con kasey cre que jam bail por escena' una las mejor part pel cul una adici que val pen comparaci con musical los bailarin cant pel cul son much superior musical com elenc que men vec grand cil hac pel cul por supuest las decor iluminaci bail cant tambi son much superior pel cul que deb esper hech entreg las cancion que estab com con musical hac mejor pel cul los nuev son bastant buen tod pel cul simplement ofrec que musical opini especial comparaci con musical que tien poc decor nic punt pel cul los cort obvi entre los actor que habl los cantant denomin durant las porcion cant par algun los personaj per bail impec product final fue agrad que musical",
#  'protocol una pel cul inver mil cuy nic graci salvador que est protagoniz por goldi hawn junt con buen elenc los actor apoy histori gir torn una camarer ctel que hac famos despu salv inadvertid vid dignatari rab histori cuest abaj mit pel cul encant goldi simplement guard esta pel cul men que seas fan tic goldi hawn salg camin par ver esta pel cul',
#  'esta pel cul podr clasific com dram teng ide fuer john voight mary steenburg estar trat borr esto fue tan exact com xen rcul abraham mois fusion lot sobrin abraham lot aparec mil antes que hub nac caneanit vag por tierr verd estab pens los guionist era sol ignor recuerd algo sobr animal lot canane tod ese tem escuel dominical estab trat ofend mer xim person planet posibl cristian jud musulman los histori arqu log log psic log ling istas hech algui ofendi cualqu que tuv nim gust habr enamor este',
#  "proston sturgis 'el pod glori erribl por blic por blic durant casi veint treint hast final cad cuand resurgi inclus present televisi mientr tant hab gan con notoried porqu libr kan citiz kan paulin kael hab suger que gui herm mankiewicz orson well par kan bas gui sturgis aqu com mencion comienz este hil par pel cul siti web imdb kael exag cas hay unos seis narrador que turn par trat vid charl fost kan peri dic que represent ralston clon henry luc las memori thatch bernstein jed leland sus alexand kan raymond mayordom cad uno tien inclinaci diferent kan reflej decepci odi hombr por supuest cad uno tambi revel sus propi fall cuand est dic versi histori kan este tod tambi conduc las frecuent reevalif superpuest del mism incident esta situaci pod glori com kan trat der empresarial legendari aqu tom garn spenc tracy hombr que levant part inferior ser jef del sistem ferroviari exit del per sol hay dos narrador son hombr man derech garn henry ralph morg espos sarah padd esto restring visi casi tridimensional que ten moment kan garn henry cuand narr est habl jef amig qui respet amab espos com voz del blic esc ptic sol las fall henry tecalpical ejempl aunqu abri camin tom conviert anti trabaj sus ltim los sinorm son problem import ser desaceler por sus shenanigans henry describ confrontaci tom con uni gran salient preocup detriment vid cas per espos henry recuerd tom usab las costr violenci par pon fin huelg aparent sopl sed uni mat much person que ten dos vist del hombr per uno blanc pur uno pur negr estoy realment llam pod glori por duplic xit kan poc pel cul inclu tod las pel cul orson well per soy conscient que histori present suficient bien com par manten inter uno hast final graci las actuacion tracy coll moor com espos sally tragedi del xit mundan parej llev complet cas cuand cas tom quier hac bien part par darl espos famili benefici que nunc tuv per ric gran xit empresarial vien cost tom involucr profund con corr imperi del ferrocarril expand mejor constant per quit demasi pierd toqu con sally tambi cuent eve hel vinson muj jov que conviert amant cuand sally enter comport infiel destru simplement tom tambi tien shock complet que conviert rtir los ojos henry eve cas con tom present hij per result ser hij eve por hij tom tom philip trent descubr este cornud incestu hac que tom disp mism pel cul xit total acci salt vec poc convincent sin embarg hac que negoci parezc real teng cuent escen cuand tom dic junt direct sobr sus plan par compr una pequ nea tren rival analiz uso las oblig par financi los plan sturgis vin fond ric por que podr tra este tip detall que general una pel cul primer tarif ning ciudadan kan quiz sin inter par los amant pel cul com intent realism empresarial con comentari social depresi ric",
#  'promedi sorprendent domestic fulci giall que signif que bastant mal por las norm normal per redim por lid acumulaci algun toqu agrad com toqu tiemp orden los problem las vision clarivident las not conoc del ner est plen march log banal actuaci mader punt parcel gic final contin much tiemp mientr que desenlac demuestr ser poc coj que dir afloj limp manej nic las norm gall divert pist amarill dond quier que est mir asesin educ',
#  "volv mar una esas pel cul sic kung que shaw produc nuev los cuy ner equivalent los occidental los espaguetis hollywood protagon gordon liu contrapart del western's clint eastwood digital remasteriz una nuev impresi hech par fant stic festival cin esto est present alcanc shaw com los buen viej tiemp esta pel cul una histori simpl buen vers cont actos que men sum sub narrat las pel cul artes marcial esa poc uno establec premis los trabaj molin tint pequ puebl est content con lot ten salari reduc los gangsters entrant manchu pued hac much por explotaci porqu ningun ellos sean expert artes marcial par asum los pandiller jef principi ten xit menor que liu hic impon monj shaolin alt calific una las mejor secuenci comedi per despert expus cuand empuj mit credibil hac pas por uno demasi vec dos muestr protagon quer volv mafi sin embarg sin artes marcial real embarc viaj shaolin templ par intent infiltr aprend artes marcial sly despu algun moment slapstick final acept abad qui imped per est decepcion por los tod ense anza poc com estil del miyagi karat kid per lug pint cerc lleg erig andami tod templ nad pued manten buen hombr haci abaj inconscient constru fuerz resistent aprend kung camin poc ortodox tres dond comienz festival luch con efect son ques cad sin contact obvi pel cul tratamient xim impact per bastant refresc observ las escen luch aqu con sus inquilin ngul ancho par resalt clarid los detall entre los soci combat uso mar lent sol par mostr truc diferent ngul pued encontr veloc combat poc demasi lent con poc paus entre los movimient per con yuen ping estil que usa nausem las pel cul hollywood segur hac escen luch com sol regres mar obtien una proyecci repet lun por que eres jueg par viaj nost lgic por memori del carril est esper",
# ...
#  'royal rumbl sid tradicional uno mis event favorit sid fan luch por los poc los otros shows pued ten mejor coincident per siempr encontr que parej real rumbl estar llen emoci voy revel los ganador ning part que veo com just par arruin los result una revisi sin embarg coment sobr calid ellos ten los part est ndar lueg gran event rumbl dos smackdown dos raw shawn michaels edge open par raw esto demuestr ser buen part dos tip talent este part que recomend ver dif cil resum sin regal ganador que ten compromis habitual contr gran monstru desagrad sea qui sea gigant gonzal yokozun kamal buen esta vez heidenreich tambi part ata pic tarif empres mir eres fan teng que admit que soy pur por factor entreten dif cilment pued ser consider com part luch libr sic los siguient dos part son los part tul por una vez smackdown logr rawstag raw part tul bastant emocion agrad per con max anti max decepcion par termin part raw asunt bastant aburr aburr que una pen que soy fan ambos chic involucr ahor raz principal encant event rumbl bastant buen este lleg event tod tuv una buen ide qui podr gan pued que sea una gran sorpres per buen muy agrad hay las divers form divers las person que elimin est chic tok que lleg anill particip que rid cul tod quer ver venc algui elimin con combatient elimin previ tien sus xim nim habitual encant final particul entrad vinc mcmahon recomend este espect cul wwe form superior per sig siend buen agr gal colecci',
#  "recuerd esto una ven simil los ven nos hund amos regres del pub ver amos esto grab amos lueg pas amos seman repet las neas entre llam uno nuestr comp eros zipmol watkins despu del brillant episodi que daniel peacock tien poc 'restyling' nariz por call espald aborcion lot grand neas recuerd las ana sol pued obten pan blanc hombr marr mal pid gandhi com comerci local tony woodcock estab definit episodi que estab ense ando ralph daniel peacock par ser barm buen amand nunc har com hombr bar hel leder ense pregunt person sobr part ves part anoch pens que woodcock jug bien despu una caden convers fall estrell del arsenal pel riz estab sent bar ves part anoch pens que jugu bien todav hac neas est pid extra ahor reg ralph ralph reg reg reg reg reg reg reg reg reg reg reg lot moment tont muy surreal cancion muy surreal los follet abortari call atr favorit personal con excelent nea final marc regres tus paquet remitent good old danny peacock agreg much algun tard los bebedor ven actualizaci encontr par episodi cint voy sub bocet gandhi youtub",
#  'destin ser sic antes que fuer conceptualiz este jueg merec tod reconoc que merec moment que los tirador primer person les gust terremot iii aren unreal torne est gan tod atenci los jugador inform tic las aventur fic son una raz moribund con gran jueg palabr humor maldici monkey island jueg que las person tod los grup edad disfrut vid sol pued mejor despu toc maldici isla los mon predicci escap secuel monkey island est destin ser sic tambi garantiz',
#  'stephan audr her homosexual este estudi bell med una pequ comun danes haci final del sigl pas dos herman herm musical talent renunci sus propi perspect felic matrimoni par cuid padr envejec una muj frances eta vien trabaj par ellos despu algun ella gan lot est decid hac algo por las herman que han llev soluci prepar una fiest exquisit suntuos que cambi vid tod los invit esta una pel cul sobr interacci human cultural reflej lenguaj cambiant del log danish franc especial entre sobried obedient protest nort europ sensual del sur cat lic tambi trat neces human calidez bond pued expres estimul trav del cultiv los sent una pel cul profund edif',
#  'esta pel cul fue demasi expert much los espect que pens que esto era incre ble deb hab estad las pel cul viej escuel porqu tod pel cul establec pas principi pens que pel cul estab mostr algo del pas que esper que eso desvanec com iluminaci los personaj que pas per sol sic esta era una pel cul trat mezcl futur con pas mezcl muy bien esta pel cul inclus con efect especial realid podr ver pantall azul con los que los actor estab trabaj hay demasi pel cul que hag exact que hic exact hiz esta pel cul por que hay raz par que los tic exager esta pel cul que dic pel cul grand que hay hech sol una mierd pal tampoc ayud que nea histori fuer tan horribl entiend por hollywood acord ten esta pel cul produc tampoc entiend los actor actric esta pel cul est dispuest estar una pel cul com esta casi com tod lean gui olvid leer letr fin har tod una comput esta fue una pel cul que deb hab estad una red cin porqu nad sobr esta pel cul fue revolucionari estoy muy molest conmig mism por pag diner par ver esto hag que hag pierd tiemp diner esta pel cul hoy ana',
#  'incre ble que hub dos pel cul con mism histori lanz este sali antes ese otro con tom cruis hic eso con trum capot mism asesin del zodiac pas interes director director dav michael latt ten presupuest stev spielberg thom howell tom cruis esta una lid imitaci del xit taquill que recaud millon tod mund acci fue nim mayor part del tiemp nos trat con llant rhett gil qui interpret pastor que estab dand por venc con god gari busey fue espeluzn comoun rcit',
#  'vec intent trat intent ser carit con tod las pel cul grad hast per vez cuand una pel cul particul sol prueb pacienci hast que dese abofet tod los murci lag que baj tul viv por noch una pel cul pued ver esto sin pens que realment deb hab sid episodi gal nocturn ningun los mejor tampoc pel cul tien algo que ver con dic que mord por bat consecuent comienz transform murci lag que beb sangr human realid piens que estab convirt gran murci lag estar com mosquit por cub gal per porqu esta una pel cul horror barat lur sangr palabr pes que tien incaut grandi got sombrer los episodi negr casi tod las noch amig comp ero dic bigot aspen extrem insist que sol tien una reacci rgic las vacun contr rabi mientr tant sheriff del cond desagrad estereotip del mund sospech que doc ser respons del asesinat brutal exanguin vari local win adem mientr tant espos del dic decid que negaci egipt altern patrocin molest distracci tant que actuaci sea mal pued dec que los actor est hac eleccion nivel profesional est trat tra algo jug vid gui inclus tip que jueg sheriff acuerd bastant mal per mal clich mader maner profesional sol que tod sobr actuaci form que pas las escen los disfrac log gui nea histori general establec sus dient bord hac quer buen abofet tod los involucr piens pel cul tuv una oportun extern ser favorit espeluzn inquiet per director ten que venc michael pataki actor experiment car cter con una sill hast que pataki acord actu sol canal weav dennis tambi necesit encontr gui que tuv poc sent con respect tod murci lag muerd human que lueg conviert escenari murci lag tambi necesit que actor que interpret dic par encontr poc sic cre ble asunt escenari par sus episodi lug recurr gin hombr tien una convulsi del littl gold book clich actting covelisss necesit volv trabaj tod personaj espos hac inteligent men inteligent men estrident waaaaay nunc volv ver voluntari esta pel cul except con ayud mik los bots mal per mal una maner tont humor stic interes mejor que battlefield earth waterworld sin embarg',
#  'gran mentir gord que obtien cuand combin una excelent escritur una gran producci nfasis ide inteligent sobr pap adolescent las dos estrell trabaj muy bien pued dec amand bynes brill pon irkel lee majors pel cul fueron brillant toqu mir esta pel cul con tus hij larg deb hab estad prest atenci',
#  'tim robbins john cusack son dos actor que apreci larg sus carrer esa fue nic raz par eleg ver esta pel cul buen tod que pued dec que arrepent total estos dos grand actor humill hast final realiz una seri irrelev inimagin kitch extrem que esto sea mal por sus propi bocet que supon que deb hac gent per hac nic raz por que pued pens que director era amig decid apoy pel cul protagoniz pued pens nad porqu esta pel cul tan barat afortun tim robbins john cusack han decepcion desd entonc recomend que evit esta pel cul men que dese opini sobr los dos actor estrop',
#  'ver esta pel cul sorprendi percepci los medi pued mold una opini las person una celebr kar carpent era una jov despreocup per muy inconfi cuy maravill voz ayud ella herman richard elev las cart con maravill cancion igual que con tod las celebr hoy menud fueron critic por sic com sus aparat estil etc esto tuv gran efect kar qui ray una batall contr pes rdid stic que eventual caus muert esta pel cul fieltr del coraz fue inicial algo que habr pens verl per comenz verl entonc estab enganch mism maner que hac histori tin turn entonc esta pel cul ilumin permit ver vid los ven int rpret actuaci fue excelent inclus despu casi despu que hic entonc direccional log todav est entreten recomend cualqu que hay vist incre blement precis carg emocional',
#  'nad sagr sol pregunt erni fosselius estos tod tien una mar vide una pel cul apen est fuer antes que las fals comienc vol escrit dispar pid menud public direct internet las falsi son calient estos nos hac tod posibl par asegur que los cineast salg propi import propi hac cuand hiz las primer guerr star fue mund diferent cin era parqu infantil unas poc fals select eran muy rar entonc dios nos dio las guerr hardwar disp par parec barat fue simplement barat audi obvi registr despu del hech eso quit experient diabl eso que hac tan genial estab crud sin pul golp implac algun los moment pretenci pel cul original desd fluk starbuck agit alrededor una lintern lug sabl luz hic eso cuand era jov par chewchill wooki monst observaci auggi ben doggi nah sol poc cabez cabez esta pel cul cort una part fen men com cualqu las pel cul real star wars alquil mpral ped prest amig que farcez est contig siempr',
#  'odi odi inan predec mism que masquerad com arte esta pel cul est pid inan eros est pid despu primer medi hor acel trav versi dvd vio los mism shennanigans juvenil una otra vez enfurec que hab pas diner gan por tramp tramp sof ric tinting drivel sepi azul hac algo una pel cul much men arte',
#  'por general trat ser profesional construct cuand critic las pel cul per dios esta fue peor pel cul que vist mal actuaci mal efect mal gui mal tod tram sig grup clich adolescent camin haci rav que llev cab luz del una isla remot sin embarg cuand lleg grup tod que encuentr una pist bail vac rop sangrient determin averigu pas con rest los asistent part conjunt del clan est una misi trav bosqu infest zombi durant esta cruz son ayud por polluel polic capit mar que sol suced par ten mer correct armas par dar cad uno los tambi nen con jonath cherry otros sobrevivient sic rest pel cul una colecci secuenci acci mal dirig inclu tirote demasi larg fuer cas los muert esta pele complet con violenci hollywood ques los clips redund del videojueg hotd las rotacion mar sloppy matrix esqu uno los voluntari inclus los personaj sacrific salv los dem por porqu fuer nobl valient per deb que part rostr escuch con cid zombi escupi despu que continu golp criatur much despu hab sid discapacit supon que deb sent pen por este tip par resum tod hay ning punt ver esta pel cul men que quier ver por mism terribl que teatr que estab estab muert que los zombi pantall estoy segur que diner que desperdici ver esta piez podr cubr cilment los cost que tom par hac grad',
#  'gust ver esto una clas histori cin algo escuel trat convenc maestr ver algo eme cualqui cos mejor que esta pel cul ritm lent confus aburr mal constru sangrient gringy necesit segu mensaj buen per los vist han manej mejor vari otras pel cul actuaci siqu buen esta pel cul inc mod que comienz ser divert sin embarg intresnsional deb histori surreal que final sol vuelv inc mod ver sent sincer sient que hor minut vid tien sid rob por algui querr ver una describ durant minut que verl conduc trav atasc fic durant minut escuch hippi que pued hac que las ovej aparezc testig una especi violaci que ver papel principal que com mar entonc esta pel cul merec nad que est content con vist previ seri soy tip ment abiert gust las pel cul que protest por simbol per esta pel cul fue muy horribl haz cualqui excus que pued par evit esta pel cul',
#  'esto com libr text zoolog dad que representaci animal tan precis sin embarg aqu est algun detall que parec hab sid liger modific durant transici pel cul las bal pistol nunc golp los dragon gigant komod import ntas vec dispar komod las bal simplement acerc ella mejor maner evit ser com por una cobr gigant gigant komod dragon sol par par excepci esta regl dich que manteng muy quiet cuy cas deb sal hast que komod est just lad lueg deb par esper derrot minut mar lent entrecort las gen detr los dit realment hac una observaci agrad una herramient mejor memori ampli sustitut par perd licenci navegaci ser arrest los miembr las unidad del rcit lit ven los dragon komod que encuentr dentr uno medidor los ser gran tam tal vez naturalez gener por comput estos dragon tien algo que ver con film una notici con objet expon las prueb ilegal animal reporter cam graf con una mar tod equip personal que necesit engranaj son una segund mar micr fon etc tod son superflu cuand escuch grit animal una person tien una pistol deb sac alarl person cercan cuand sac arma son segur que est quit inclus ded est cerc los reporter segur acuerd medi camin tod mund par expon algo sin ten menor ide que est expon investigaci antecedent conoc vag est fuer mod period modern las pistol tien men bal clip lueg que siguient clip pes eso aquell con armas afirm que necesit municion las mar car tambi recuerd que reporter sol tien una mar regular dej atr sin siqu moment vacilaci arrepent estas mar logr regres report por mism chic rubi realment est pid mism chic que dic que entra una cas porqu drag komod pued corr cilment trav haci ndol insegur tom equip edifici hech del mism material par protecci nadi dic una palabr respect las instal alta tecnolog parec oficin simpl con mic secundari las serpient modific gen tic crec desd tam normal pies larg cuesti per crec absolut las seman ambos lad los militar destru form rutinari las islas complet cuand las person cumpl con los plaz contact los hombr con armas necesari cambi direcci est dispar cuand objet est just delant ellos lug simplement sig dispar air cuant busc usted mayor ser posibil sobreviv las criatur gigant intuici las mujer suficient confiabl par cambi inclus ment obstin las ment cualqui moment que est siend caz por las criatur gigant son buen moment par golp las mit edad los ruid animal son ruid enmascar adecu par jur mism volum',
#  ...]

# %%
corpus_es_mixed = " ".join(corpus_es)
word_cloud4 = WordCloud(collocations = False, background_color = 'white', width = 2048, height = 1080).generate(corpus_es_mixed)
plt.imshow(word_cloud4, interpolation='bilinear')
plt.axis("off")
plt.show()

# %% [markdown]
# ## 2.3 Transformación a Embeddings (5 puntos)

# %% [markdown]
# Transforme los reviews en español a vectores (embeddings)

# %% [markdown]
# **RESPUESTA**:

# %% [markdown]
# ## TODO: Duda, se hace sobre el corpus tokenizado?

# %%
corpus_es_def = [review.split() for review in corpus_es]

# %%
from gensim.models import Word2Vec
model = Word2Vec(sentences=corpus_es_def, vector_size=100, window=5, min_count=1, workers=4, sg=1)  # Se realiza usando skip-grams
# ya con este modelo se

# %%
model.wv.vectors.shape  # Clatramente tienen sentido las dimensiones que entrega el embbeding del modelo
# Out:
# (114498, 100)

# %%
# Se utiliza el modelo de W2V para generar el embedding de palabras mediante el promedio de los embedding de cada palabra
def embed_review(review):
    return np.mean(model.wv[review], axis=0)
X_es = np.array([embed_review(review) for review in corpus_es_def])

# %% [markdown]
# ## 2.4 Generación de gráficos (5 puntos)

# %% [markdown]
# Utilice PCA con 3 componentes sobre los embeddings

# %% [markdown]
# **RESPUESTA**:

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=3)
X_es_3d = pca.fit_transform(X_es)
print(f"Varianza total explica {sum(pca.explained_variance_ratio_)}")
# Out:
# Varianza total explica 0.7113266121596098

# %% [markdown]
# Realizando lo anterior, se podría considerar como puntos en 3D y nos permite visualizar en el espacio. Realice una visualización de los puntos en 3D, coloreando cada clase.

# %% [markdown]
# **RESPUESTA**:

# %%
df_toplot = pd.DataFrame(X_es_3d, columns=['PCA1', 'PCA2', 'PCA3'])
df_toplot["Clases"] = df["sentimiento"]
# Se filtran los PCA asociados a cada sentimiento para plotearlos de manera segmentada
fig = plt.figure(figsize = (12, 6))
ax = plt.axes(projection='3d')
colores = {"positivo": "blue", "negativo": "red"}
cmap = df_toplot["Clases"].map(colores).to_numpy()
ax.scatter(df_toplot["PCA1"], df_toplot["PCA2"], df_toplot["PCA3"],c=cmap, alpha=0.7)
ax.set_title('Plot 3d PCA por clases')
# Para la leyenda
for clase, color in colores.items():
    ax.scatter([], [], [], c=color, label=clase)
ax.legend(title="Clases")
plt.show()

# %% [markdown]
# Utilice t-SNE y vuelva realizar el gráfico

# %% [markdown]
# **RESPUESTA**:

# %%
from sklearn.manifold import TSNE
# Para hacer más rápido se hace T-SNE al resultado de hacer PCA que conserva el 95% de la varianza
pca_2 = PCA(n_components=0.95)
tsne = TSNE(n_components=3, random_state=42)
X_es_tsne = tsne.fit_transform(pca_2.fit_transform(X_es))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[61], line 5
#       3 pca_2 = PCA(n_components=0.95)
#       4 tsne = TSNE(n_components=3, random_state=42)
# ----> 5 X_es_tsne = tsne.fit_transform(pca_2.fit_transform(X_es))
#
# File c:\Users\ignav\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\_set_output.py:316, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     314 @wraps(f)
#     315 def wrapped(self, X, *args, **kwargs):
# --> 316     data_to_wrap = f(self, X, *args, **kwargs)
#     317     if isinstance(data_to_wrap, tuple):
#     318         # only wrap the first output for cross decomposition
#     319         return_tuple = (
#     320             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     321             *data_to_wrap[1:],
#     322         )
#
# File c:\Users\ignav\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:1473, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1466     estimator._validate_params()
#    1468 with config_context(
#    1469     skip_parameter_validation=(
#    1470         prefer_skip_nested_validation or global_skip_validation
#    1471     )
#    1472 ):
# -> 1473     return fit_method(estimator, *args, **kwargs)
#
# File c:\Users\ignav\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\manifold\_t_sne.py:1176, in TSNE.fit_transform(self, X, y)
#    1173     self._max_iter = self.max_iter
#    1175 self._check_params_vs_input(X)
# -> 1176 embedding = self._fit(X)
#    1177 self.embedding_ = embedding
#    1178 return self.embedding_
#
# File c:\Users\ignav\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\manifold\_t_sne.py:1044, in TSNE._fit(self, X, skip_num_points)
#    1038 # Degrees of freedom of the Student's t-distribution. The suggestion
#    1039 # degrees_of_freedom = n_components - 1 comes from
#    1040 # "Learning a Parametric Embedding by Preserving Local Structure"
#    1041 # Laurens van der Maaten, 2009.
#    1042 degrees_of_freedom = max(self.n_components - 1, 1)
# -> 1044 return self._tsne(
#    1045     P,
#    1046     degrees_of_freedom,
#    1047     n_samples,
#    1048     X_embedded=X_embedded,
#    1049     neighbors=neighbors_nn,
#    1050     skip_num_points=skip_num_points,
#    1051 )
#
# File c:\Users\ignav\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\manifold\_t_sne.py:1112, in TSNE._tsne(self, P, degrees_of_freedom, n_samples, X_embedded, neighbors, skip_num_points)
#    1110     opt_args["momentum"] = 0.8
#    1111     opt_args["n_iter_without_progress"] = self.n_iter_without_progress
# -> 1112     params, kl_divergence, it = _gradient_descent(obj_func, params, **opt_args)
#    1114 # Save the final number of iterations
#    1115 self.n_iter_ = it
#
# File c:\Users\ignav\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\manifold\_t_sne.py:403, in _gradient_descent(objective, p0, it, max_iter, n_iter_check, n_iter_without_progress, momentum, learning_rate, min_gain, min_grad_norm, verbose, args, kwargs)
#     400 # only compute the error when needed
#     401 kwargs["compute_error"] = check_convergence or i == max_iter - 1
# --> 403 error, grad = objective(p, *args, **kwargs)
#     405 inc = update * grad < 0.0
#     406 dec = np.invert(inc)
#
# File c:\Users\ignav\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\manifold\_t_sne.py:284, in _kl_divergence_bh(params, P, degrees_of_freedom, n_samples, n_components, angle, skip_num_points, verbose, compute_error, num_threads)
#     281 indptr = P.indptr.astype(np.int64, copy=False)
#     283 grad = np.zeros(X_embedded.shape, dtype=np.float32)
# --> 284 error = _barnes_hut_tsne.gradient(
#     285     val_P,
#     286     X_embedded,
#     287     neighbors,
#     288     indptr,
#     289     grad,
#     290     angle,
#     291     n_components,
#     292     verbose,
#     293     dof=degrees_of_freedom,
#     294     compute_error=compute_error,
#     295     num_threads=num_threads,
#     296 )
#     297 c = 2.0 * (degrees_of_freedom + 1.0) / degrees_of_freedom
#     298 grad = grad.ravel()
#
# KeyboardInterrupt:

# %%
# De la misma manera que como se hizo para PCA
df_toplot_TSNE = pd.DataFrame(X_es_tsne, columns=['T_SNE1', 'T_SNE2', 'T_SNE3'])
df_toplot_TSNE["Clases"] = df["sentimiento"]
fig = plt.figure(figsize = (12, 6))
ax = plt.axes(projection='3d')
colores = {"positivo": "blue", "negativo": "red"}
cmap = df_toplot_TSNE["Clases"].map(colores).to_numpy()
ax.scatter(df_toplot_TSNE["T_SNE1"], df_toplot_TSNE["T_SNE2"], df_toplot_TSNE["T_SNE3"],c=cmap, alpha=0.7)
ax.set_title('Plot 3d T-SNE por clases')
# Para la leyenda
for clase, color in colores.items():
    ax.scatter([], [], [], c=color, label=clase)
ax.legend(title="Clases")
plt.show()

# %% [markdown]
# ¿Qué se puede concluir con las visualizaciones realizadas por las dos reducciones de dimensionalidad?

# %% [markdown]
# **RESPUESTA**:

# %% [markdown]
# ¿Qué limitaciones tiene utilizar reducción de dimensionalidad en los embeddings? ¿Los usaría para entrenar?

# %% [markdown]
# **RESPUESTA**:

# %% [markdown]
# TODO: Revisar. El utilizar reducción de dimensionalidad en los embeddings tiene la limitación de perder información (lo que se puede ver por ejemplo en el caso de PCA donde la varianza explicada no cubre toda la del espacio original) valiosa asociada a los datos (en específico del contexto de los mismo, CREO), por lo que si se usan para entrenar se obtiene un modelo subóptimo. Sin embargo, en caso de tener limitaciones de recursos computacionales puede ser una buena opción trabajar con reducción de dimensionalidad pues se gana múchisimo en memoria utilizada.

# %% [markdown]
# # Parte 3: Análisis de Sentimiento (25 puntos)

# %% [markdown]
# ### Parte 3.1: Pruebas de Análisis de Sentimiento (4 puntos)

# %% [markdown]
# Usar la librería de Textblob para la actividad.

# %% [markdown]
# Cargue el dataset proveniente de: https://huggingface.co/datasets/mltrev23/financial-sentiment-analysis/blob/main/archive.zip

# %% [markdown]
# **RESPUESTA**:

# %% [markdown]
# Escoja dos documentos y utilice TextBlob sobre ellos.
# Métodos a utilizar: tags, sentiment, polarity, subjectivity y words

# %% [markdown]
# **RESPUESTA**:

# %% [markdown]
# ¿Qué es lo que señala TextBlob en los documentos seleccionados? ¿Funciona correctamente? Justifique. Hint: Para ver si funciona correctamente compare los resultados obtenidos con los labels del dataset y si la Sentence es acorde a los resultados obtenidos

# %% [markdown]
# **RESPUESTA**:

# %% [markdown]
# Pruebe utilizando TextBlob con la frase de Beneditti ‘De qué sirve querer olvidar, a veces simplemente se trata de aprender a vivir con eso’. Luego pruebe la segunda frase 'La vida es una lucha constante'. Justifique los resultados.

# %% [markdown]
# **RESPUESTA**:

# %% [markdown]
# ¿Qué haría usted para mejorar la clasificación de análisis de sentimiento para el idioma Español pero dando prioridad a como hablamos los chilenos?

# %% [markdown]
# **RESPUESTA**:

# %% [markdown]
# ¿Podría haber problemas al realizar el análisis de sentimiento para un español generalizado y en particular con insultos? Explique

# %% [markdown]
# **RESPUESTA**:

# %% [markdown]
# #### Lectura Opcional: Hay una librería llamada `vaderSentiment` que puede ser útil para el análisis de sentimientos. Además hay otro paquete que permite analizar el sentimiento en varios idiomas llamado `vader-multi`.
# https://github.com/brunneis/vader-multi

# %% [markdown]
# ### Parte 3.2: Clasificación de análisis de sentimiento con Word2Vec (9 puntos)

# %% [markdown]
# Haga un procesamiento de los datos (Sentences)

# %% [markdown]
# **RESPUESTA**:

# %% [markdown]
# Guarde los labels en una variable y

# %% [markdown]
# **RESPUESTA**:

# %% [markdown]
# Transforme el texto a embeddings. Probablemente necesites tener vectores de tamaño fijo, así que considera usar un enfoque como padding o truncamiento.

# %% [markdown]
# **RESPUESTA**:

# %% [markdown]
# Divida los datos en conjuntos de entrenamiento y prueba. Además crea un array de índices para utilizar en el train_test_split. Es importante para utilizar en el LimeExplainer después.

# %% [markdown]
# **RESPUESTA**:

# %% [markdown]
# Utilice el modelo (SGD  o regresión logística) para clasificar las 3 clases y muestre la matriz de confusión

# %% [markdown]
# **RESPUESTA**:

# %% [markdown]
# Utilice LimeTextExplainer para interpretar las predicciones de su modelo. Esto le permitirá entender qué palabras o frases están influyendo más en las decisiones del clasificador.

# %% [markdown]
# HINT: Cree una funcion que reciba los textos, use el tokenize y agregalos en una lista. Luego utilice el modelo para predecir sobre la lista de los embeddings. LimeTextExplainer necesita una función que reciba los textos.

# %% [markdown]
# **RESPUESTA**:

# %% [markdown]
# ¿Los resultados fueron buenos o malos? Fundamente

# %% [markdown]
# **RESPUESTA:**

# %% [markdown]
# ¿Cómo mejoraría el modelo?

# %% [markdown]
# **RESPUESTA:**

# %% [markdown]
# ### Parte 3.3: Clasificación de análisis de sentimiento con GloVe (12 puntos)

# %% [markdown]
# Muestre los modelos que contiene gensim (código de clases o formativa)

# %% [markdown]
# **RESPUESTA**:

# %% [markdown]
# Cargue algunos de los modelos anteriores (ej: glove-wiki-gigaword-50)

# %% [markdown]
# **RESPUESTA**:

# %% [markdown]
# Transforme el texto a embeddings utilizando GloVe

# %% [markdown]
# **RESPUESTA**:

# %% [markdown]
# Crear un MLP que clasifique entre las 3 clases. Recordar lo utilizado para LimeText.

# %% [markdown]
# **RESPUESTA**:

# %% [markdown]
# Utilice LimeTextExplainer para interpretar las predicciones de su modelo.

# %% [markdown]
# **RESPUESTA**:

# %% [markdown]
# ¿Por qué es mejor este último clasificador?

# %% [markdown]
# **RESPUESTA**:
